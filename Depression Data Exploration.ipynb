# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install mne
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 38.4 MB/s eta 0:00:00
# ...

# %%
import mne
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
raw = mne.io.read_raw_edf('/content/drive/MyDrive/Depression Research/HS1EC.edf')
# Out:
# Extracting EDF parameters from /content/drive/MyDrive/Depression Research/HS1EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...

# %%
raw.plot(start=0,duration=1)
# Out:
# Using matplotlib as 2D backend.
# <MNEBrowseFigure size 800x800 with 4 Axes>
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %%
raw
# Out:
# <RawEDF | HS1EC.edf, 22 x 76800 (300.0 s), ~26 kB, data not loaded>

# %%
df = raw.to_data_frame()

# %%
#df = df.transpose()

# %%
df
# Out:
#              time  EEG Fp1-LE  EEG F3-LE  EEG C3-LE  EEG P3-LE  EEG O1-LE  \
# 0        0.000000   -5.150393  -8.850675 -11.750896 -11.150851  -2.350179
# 1        0.003906   -7.250553 -12.050919 -20.551568 -17.151308  -8.650660
# 2        0.007812   -8.750668 -15.051148 -29.052216 -20.851591 -13.151003
# 3        0.011719   -8.450645 -15.851209 -32.552483 -21.351629 -15.051148
# 4        0.015625   -4.650355 -12.650965 -28.352163 -18.351400 -13.951064
# ...           ...         ...        ...        ...        ...        ...
# 76795  299.980469   -2.450187   2.250172   8.450645   9.450721   2.550195
# 76796  299.984375   -2.750210   3.250248  12.850980  13.050996   5.450416
# 76797  299.988281   -1.350103   3.350256  15.051148  15.851209   7.250553
# 76798  299.992188    1.550118   3.550271  15.151156  17.851362   8.550652
# 76799  299.996094    4.650355   3.650278  13.651041  18.751431   9.750744
#
#        EEG F7-LE  EEG T3-LE  EEG T5-LE  EEG Fz-LE  ...  EEG P4-LE  EEG O2-LE  \
# ...

# %%
df.columns
# Out:
# Index(['time', 'EEG Fp1-LE', 'EEG F3-LE', 'EEG C3-LE', 'EEG P3-LE',
#        'EEG O1-LE', 'EEG F7-LE', 'EEG T3-LE', 'EEG T5-LE', 'EEG Fz-LE',
#        'EEG Fp2-LE', 'EEG F4-LE', 'EEG C4-LE', 'EEG P4-LE', 'EEG O2-LE',
#        'EEG F8-LE', 'EEG T4-LE', 'EEG T6-LE', 'EEG Cz-LE', 'EEG Pz-LE',
#        'EEG A2-A1', 'EEG 23A-23R', 'EEG 24A-24R'],
#       dtype='object')

# %%
df = df[['EEG Fp2-LE','EEG F8-LE','EEG O2-LE','EEG Fp1-LE','EEG F7-LE','EEG O1-LE','EEG F4-LE','EEG C4-LE','EEG P4-LE','EEG F3-LE', 'EEG C3-LE', 'EEG P3-LE','EEG Fz-LE','EEG Cz-LE', 'EEG Pz-LE']]

# %%
df
# Out:
#        EEG Fp2-LE  EEG F8-LE  EEG O2-LE  EEG Fp1-LE  EEG F7-LE  EEG O1-LE  \
# 0      -13.050996  -4.450340  -1.750134   -5.150393 -10.450797  -2.350179
# 1      -13.951064  -5.450416  -2.950225   -7.250553 -14.951141  -8.650660
# 2      -11.250858  -2.450187  -3.450263   -8.750668 -20.751583 -13.151003
# 3       -6.250477   3.350256  -3.350256   -8.450645 -23.951827 -15.051148
# 4       -0.150011  10.350790  -2.550195   -4.650355 -21.351629 -13.951064
# ...           ...        ...        ...         ...        ...        ...
# 76795   -0.050004   8.750668  -6.550500   -2.450187  -8.050614   2.550195
# 76796   -1.650126   7.950607  -6.850523   -2.750210  -9.050690   5.450416
# 76797   -2.350179   6.950530  -5.750439   -1.350103  -9.750744   7.250553
# 76798   -0.750057   6.950530  -3.250248    1.550118  -8.450645   8.550652
# 76799    2.450187   8.350637   0.250019    4.650355  -5.850446   9.750744
#
#        EEG F4-LE  EEG C4-LE  EEG P4-LE  EEG F3-LE  EEG C3-LE  EEG P3-LE  \
# ...

# %%
df.describe()
# Out:
#          EEG Fp2-LE     EEG F8-LE     EEG O2-LE    EEG Fp1-LE     EEG F7-LE  \
# count  76800.000000  76800.000000  76800.000000  76800.000000  76800.000000
# mean       0.048521      0.060372      0.047169      0.045502      0.037404
# std       17.187140     14.714634      8.773610     17.592045     15.795015
# min     -178.763638   -102.057786    -56.554314   -193.164736   -187.164279
# 25%       -7.550576     -7.750591     -5.350408     -7.650584     -7.750591
# 50%       -0.250019     -0.250019      0.050004     -0.150011      0.050004
# 75%        7.450568      7.550576      5.550423      7.450568      7.750591
# max      136.260395    134.460258     50.953887    153.961746    152.861662
#
#           EEG O1-LE     EEG F4-LE     EEG C4-LE     EEG P4-LE     EEG F3-LE  \
# count  76800.000000  76800.000000  76800.000000  76800.000000  76800.000000
# mean       0.046837      0.047687      0.046661      0.045601      0.044178
# ...

# %%
df.isnull().sum()
# Out:
# EEG Fp2-LE    0
# EEG F8-LE     0
# EEG O2-LE     0
# EEG Fp1-LE    0
# EEG F7-LE     0
# EEG O1-LE     0
# EEG F4-LE     0
# EEG C4-LE     0
# EEG P4-LE     0
# EEG F3-LE     0
# EEG C3-LE     0
# EEG P3-LE     0
# EEG Fz-LE     0
# EEG Cz-LE     0
# EEG Pz-LE     0
# dtype: int64

# %%
raw = mne.io.read_raw_edf('/content/drive/MyDrive/Depression Research/Depressed/MDD S10 EC.edf')
# Out:
# Extracting EDF parameters from /content/drive/MyDrive/Depression Research/Depressed/MDD S10 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...

# %%
raw.plot(start=0,duration=1)
# Out:
# <MNEBrowseFigure size 800x800 with 4 Axes>
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %%
df = raw.to_data_frame()
df = df[['EEG Fp2-LE','EEG F8-LE','EEG O2-LE','EEG Fp1-LE','EEG F7-LE','EEG O1-LE','EEG F4-LE','EEG C4-LE','EEG P4-LE','EEG F3-LE', 'EEG C3-LE', 'EEG P3-LE','EEG Fz-LE','EEG Cz-LE', 'EEG Pz-LE']]
df
# Out:
#        EEG Fp2-LE  EEG F8-LE  EEG O2-LE  EEG Fp1-LE  EEG F7-LE  EEG O1-LE  \
# 0      -11.250858 -12.850980  -2.750210   -7.550576   6.350484  -0.750057
# 1       -8.950683 -12.050919  -0.550042   -6.050462   1.450111   1.050080
# 2       -4.850370  -8.350637  -1.050080   -4.350332  -5.150393   0.250019
# 3       -0.050004  -3.150240  -3.950301   -3.450263 -10.750820  -3.050233
# 4        3.350256   0.950072  -7.850599   -3.650278 -12.950988  -7.750591
# ...           ...        ...        ...         ...        ...        ...
# 77051  -11.950912  -6.650507  -2.750210   -7.950607  -5.250401  -4.650355
# 77052   -9.750744  -4.150317  -4.050309   -5.850446  -3.250248  -6.250477
# 77053   -8.750668  -3.550271  -6.350484   -4.950378  -1.550118  -8.650660
# 77054   -8.350637  -4.350332  -9.250706   -5.050385  -0.250019 -11.150851
# 77055   -7.950607  -5.450416 -12.050919   -5.350408   0.850065 -13.251011
#
#        EEG F4-LE  EEG C4-LE  EEG P4-LE  EEG F3-LE  EEG C3-LE  EEG P3-LE  \
# ...

# %%
df.describe()
# Out:
#          EEG Fp2-LE     EEG F8-LE     EEG O2-LE    EEG Fp1-LE     EEG F7-LE  \
# count  77056.000000  77056.000000  77056.000000  77056.000000  77056.000000
# mean       0.052296      0.053473      0.050234      0.052397      0.051055
# std        6.152413      6.343526      6.154964      5.919335      6.541600
# min      -44.153368    -41.453162    -35.752728    -40.753109    -64.054887
# 25%       -3.850294     -3.850294     -3.750286     -3.650278     -3.950301
# 50%        0.050004     -0.050004      0.050004      0.050004      0.050004
# 75%        3.850294      3.750286      3.850294      3.750286      4.050309
# max       45.353460     41.853193     37.552865     38.652949     59.954574
#
#           EEG O1-LE     EEG F4-LE     EEG C4-LE     EEG P4-LE     EEG F3-LE  \
# count  77056.000000  77056.000000  77056.000000  77056.000000  77056.000000
# mean       0.049294      0.055095      0.057372      0.053973      0.052972
# ...

# %%
df.isnull().sum()
# Out:
# EEG Fp2-LE    0
# EEG F8-LE     0
# EEG O2-LE     0
# EEG Fp1-LE    0
# EEG F7-LE     0
# EEG O1-LE     0
# EEG F4-LE     0
# EEG C4-LE     0
# EEG P4-LE     0
# EEG F3-LE     0
# EEG C3-LE     0
# EEG P3-LE     0
# EEG Fz-LE     0
# EEG Cz-LE     0
# EEG Pz-LE     0
# dtype: int64

# %%
type(df['EEG Fp2-LE'])
# Out:
# pandas.core.series.Series

# %%
Y_coord1 = df['EEG Fp2-LE'].values

# %%
Y_coord1 = Y_coord1[:256]

# %%
Y_coord1.shape
# Out:
# (256,)

# %%
X_coord1 = []
for i in range(0,256):
  X_coord1.append(i)

# %%
plt.plot(X_coord1,Y_coord1)
plt.show()

# %%
df_stats = df.describe()
df_stats = df_stats.transpose()
df_stats
# Out:
#               count      mean        std         min       25%       50%  \
# EEG Fp2-LE  77056.0  0.052296   6.152413  -44.153368 -3.850294  0.050004
# EEG F8-LE   77056.0  0.053473   6.343526  -41.453162 -3.850294 -0.050004
# EEG O2-LE   77056.0  0.050234   6.154964  -35.752728 -3.750286  0.050004
# EEG Fp1-LE  77056.0  0.052397   5.919335  -40.753109 -3.650278  0.050004
# EEG F7-LE   77056.0  0.051055   6.541600  -64.054887 -3.950301  0.050004
# EEG O1-LE   77056.0  0.049294   6.252781  -37.852888 -3.750286  0.050004
# EEG F4-LE   77056.0  0.055095   8.355576  -78.856016 -4.750362  0.050004
# EEG C4-LE   77056.0  0.057372   9.522117  -82.656306 -5.050385  0.050004
# EEG P4-LE   77056.0  0.053973   8.359328  -66.355062 -4.750362  0.050004
# EEG F3-LE   77056.0  0.052972   8.230327  -69.355291 -4.750362  0.050004
# EEG C3-LE   77056.0  0.050946  10.177146  -95.057252 -5.550423  0.050004
# EEG P3-LE   77056.0  0.050688   8.566700  -67.255131 -4.850370  0.050004
# ...

# %%
def norm(X):
  return (X-df_stats['mean'])/df_stats['std']

# %%
df = norm(df)

# %%
Y_coord2 = df['EEG Fp2-LE'].values

# %%
Y_coord2 = Y_coord2[:256]

# %%
Y_coord2.shape
# Out:
# (256,)

# %%
plt.plot(X_coord1,Y_coord2)
plt.show()
